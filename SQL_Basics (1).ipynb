# %%
#Q1. Create a New Database and  Table for Employees Task: Create a new database named  company_db and Create a table named employees columns:

"""

show databases ;
create database company_db;
use company_db;

create table Employees (
Empid int,
Firstname varchar(50),
Lastname varchar(50),
Department varchar(50),
Salary int,
Hire_date date
);

"""
# Out:
# '\n\nshow databases ;\ncreate database company_db;\nuse company_db;\n\ncreate table Employees (\nEmpid int,\nFirstname varchar(50),\nLastname varchar(50),\nDepartment varchar(50),\nSalary int,\nHire_date date\n);\n\n'

# %%
#Q2. Insert Data into Employees Table Task:  Insert the following sample records into the employees table

"""

USE mydatabase;

CREATE TABLE Company_db (
    Employeeid INT PRIMARY KEY,
    Firstname VARCHAR(50),
    Lastname VARCHAR(50),
    Department VARCHAR(50),
    Salary INT,
    Hire_date DATE
);

INSERT INTO Company_db (Employeeid, Firstname, Lastname, Department, Salary, Hire_date) VALUES
(101, 'Amit', 'Sharma', 'HR', 50000, '2020-01-15'),
(102, 'Riya', 'Kapoor', 'Sales', 75000, '2019-03-22'),
(103, 'Raj', 'Mehta', 'IT', 90000, '2018-07-11'),
(104, 'Neha', 'Verma', 'IT', 85000, '2021-09-01'),
(105, 'Arun', 'Singh', 'Finance', 60000, '2022-02-01');

SELECT * FROM Company_db;

"""
# Out:
# "\n\nUSE mydatabase;\n\nCREATE TABLE Company_db (\n    Employeeid INT PRIMARY KEY,\n    Firstname VARCHAR(50),\n    Lastname VARCHAR(50),\n    Department VARCHAR(50),\n    Salary INT,\n    Hire_date DATE\n);\n\nINSERT INTO Company_db (Employeeid, Firstname, Lastname, Department, Salary, Hire_date) VALUES\n(101, 'Amit', 'Sharma', 'HR', 50000, '2020-01-15'),\n(102, 'Riya', 'Kapoor', 'Sales', 75000, '2019-03-22'),\n(103, 'Raj', 'Mehta', 'IT', 90000, '2018-07-11'),\n(104, 'Neha', 'Verma', 'IT', 85000, '2021-09-01'),\n(105, 'Arun', 'Singh', 'Finance', 60000, '2022-02-01');\n\nSELECT * FROM Company_db;\n\n"

# %%
#Q3. Display All Employee Records Sorted by Salary (Lowest to Highest) Hint: Use the ORDER BY clause on the salary column.

"""

select * from employees
order by salary ASC;

"""
# Out:
# '\n\nselect * from employees\norder by salary ASC;\n\n'

# %%
#Q4. Show Employees Sorted by Department (A–Z) and Salary (High → Low)

"""
select * from employees
order by department ASC, salary DESC;

"""
# Out:
# '\nselect * from employees\norder by department ASC, salary DESC;\n\n'

# %%
#Q5. List All Employees in the IT Department, Ordered by Hire Date (Newest First)

"""
SELECT * FROM employees
WHERE department = 'IT'
ORDER BY hire_date DESC;

"""
# Out:
# "\nSELECT * FROM employees\nWHERE department = 'IT'\nORDER BY hire_date DESC;\n\n"

# %%
#Q6. Create and Populate a Sales Table Task: Create a table  sales to track sales data:

"""
CREATE TABLE sales (
    sale_id INT PRIMARY KEY,
    customer_name VARCHAR(50),
    amount INT,
    sale_date DATE
);
INSERT INTO sales VALUES
(1, 'Aditi', 1500, '2024-08-01'),
(2, 'Rohan', 2200, '2024-08-03'),
(3, 'Aditi', 3500, '2024-09-05'),
(4, 'Meena', 2700, '2024-09-15'),
(5, 'Rohan', 4500, '2024-09-25');

"""
# Out:
# "\nCREATE TABLE sales (\n    sale_id INT PRIMARY KEY,\n    customer_name VARCHAR(50),\n    amount INT,\n    sale_date DATE\n);\nINSERT INTO sales VALUES\n(1, 'Aditi', 1500, '2024-08-01'),\n(2, 'Rohan', 2200, '2024-08-03'),\n(3, 'Aditi', 3500, '2024-09-05'),\n(4, 'Meena', 2700, '2024-09-15'),\n(5, 'Rohan', 4500, '2024-09-25');\n\n"

# %%
#Q7. Display All Sales Records Sorted by Amount (Highest → Lowest) Hint: Use ORDER BY amount DESC

"""
SELECT * FROM sales
ORDER BY amount DESC;

"""
# Out:
# '\nSELECT * FROM sales\nORDER BY amount DESC;\n\n'

# %%
#Q8. Show All Sales Made by Customer “Aditi” Hint: Use WHERE customer_name = 'Aditi'.

"""
SELECT * FROM sales
WHERE customer_name = 'Aditi';

"""
# Out:
# "\nSELECT * FROM sales\nWHERE customer_name = 'Aditi';\n\n"

# %%
#Q9. What is the Difference Between a Primary Key and a Foreign Key?

"""

Primary Key = identity
Foreign Key = relationship

"""
# Out:
# '\n\nPrimary Key = identity\nForeign Key = relationship\n\n'

# %%
#Q10. What Are Constraints in SQL and Why Are They Used?

"""

PRIMARY KEY → unique + not null
FOREIGN KEY → relationship between tables
NOT NULL → cannot be empty
UNIQUE → no duplicate values
CHECK → condition (e.g., salary > 0)
DEFAULT → default value

"""
# Out:
# '\n\nPRIMARY KEY → unique + not null\nFOREIGN KEY → relationship between tables\nNOT NULL → cannot be empty\nUNIQUE → no duplicate values\nCHECK → condition (e.g., salary > 0)\nDEFAULT → default value\n\n'
